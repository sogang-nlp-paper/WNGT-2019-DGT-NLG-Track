# %% [markdown]
# # RotoWire dataset

# %% [markdown]
# ## 1. Basic Stats
# ![stats](datastat.png)
# Summaries are written by professionals. The writing is colloquial but relatively **well structured**.

# %% [markdown]
# ## 2. EDA

# %%
import random
from collections import defaultdict

import pandas as pd
from IPython.core.display import display, HTML

pd.set_option('display.max_columns', 30)
display(HTML("<style>.container { width:100% !important; }</style>")) # expand cell width for visibility
# Out:
# <style>.container { width:100% !important; }</style>

# %%
train_path = 'data/rotowire/train.json'
valid_path = 'data/rotowire/valid.json'
test_path = 'data/rotowire/test.json'

train = pd.read_json(train_path)
valid = pd.read_json(valid_path)
test = pd.read_json(test_path)

# %% [markdown]
# ### 2.1 raw data
# - box_score: 선수들의 기록. 그런데 선수별로 정리되어있지 않음
# - home_line: 홈팀 기록
# - vis_line: 원정팀 기록
# - summary: '정답' text

# %%
train.head()
# Out:
#                                            box_score     day    home_city  \
# 0  {'FIRST_NAME': {'24': 'Ron', '25': 'Sasha', '2...  122516     New York
# 1  {'TO': {'24': 'N/A', '25': 'N/A', '20': '2', '...   40415      Phoenix
# 2  {'FIRST_NAME': {'24': 'Shabazz', '20': 'Al-Far...   32817     Portland
# 3  {'TO': {'24': 'N/A', '25': 'N/A', '20': '0', '...  110314  Los Angeles
# 4  {'TO': {'24': '1', '25': '0', '20': '0', '21':...  121916      Chicago
#
#                                            home_line      home_name  \
# 0  {'TEAM-PTS_QTR2': '20', 'TEAM-FT_PCT': '89', '...         Knicks
# 1  {'TEAM-PTS_QTR2': '34', 'TEAM-FT_PCT': '76', '...           Suns
# 2  {'TEAM-PTS_QTR2': '34', 'TEAM-FT_PCT': '73', '...  Trail Blazers
# 3  {'TEAM-PTS_QTR2': '30', 'TEAM-FT_PCT': '88', '...       Clippers
# 4  {'TEAM-PTS_QTR2': '34', 'TEAM-FT_PCT': '100', ...          Bulls
#
#                                              summary vis_city  \
# 0  [The, Celtics, saw, great, team, play, in, the...   Boston
# 1  [The, Phoenix, Suns, (, 39, -, 38, ), escaped,...     Utah
# 2  [The, host, Portland, Trail, Blazers, defeated...   Denver
# 3  [The, Los, Angeles, Clippers, (, 3, -, 1, ), d...     Utah
# 4  [Wire-to-wire, wins, are, uncommon, in, the, N...  Detroit
#
#                                             vis_line vis_name
# 0  {'TEAM-PTS_QTR2': '34', 'TEAM-FT_PCT': '75', '...  Celtics
# 1  {'TEAM-PTS_QTR2': '19', 'TEAM-FT_PCT': '83', '...     Jazz
# 2  {'TEAM-PTS_QTR2': '29', 'TEAM-FT_PCT': '80', '...  Nuggets
# 3  {'TEAM-PTS_QTR2': '23', 'TEAM-FT_PCT': '79', '...     Jazz
# 4  {'TEAM-PTS_QTR2': '15', 'TEAM-FT_PCT': '85', '...  Pistons

# %% [markdown]
# ### 2.2 column별로 보기
# #### 2.2.1 boxscore 선수별로 보기

# %%
def get_ith_record(data, i):
    assert i is None or i <= len(data)
    if i is None:
        i = random.randint(0, len(data))
    return data.iloc[i, :]

# %%
def view_player_stat(data, i=None):
    """i번째 경기 기록 중 box score을 선수별로 정리하기"""
    record = get_ith_record(data, i)
    boxscore = record['box_score']
    idx_to_name = boxscore['PLAYER_NAME']
    boxscore_by_player = defaultdict(dict)
    for r_type, r_entity_value in boxscore.items():
        # if 'NAME' in r_type: continue
        for entity_idx, value in r_entity_value.items():
            boxscore_by_player[idx_to_name[entity_idx]][r_type] = value
    return pd.DataFrame.from_dict(boxscore_by_player, orient='index')

# %%
i = 3
view_player_stat(train)
# Out:
#                   TO FIRST_NAME MIN REB FG3A        PLAYER_NAME AST FG3M OREB  \
# Aaron Gordon       2      Aaron  31  16    0       Aaron Gordon   0    0    6
# Andrew Nicholson   0     Andrew   3   0    0   Andrew Nicholson   0    0    0
# Boban Marjanovic   0      Boban   3   0    0   Boban Marjanovic   0    0    0
# Boris Diaw         0      Boris  17   6    0         Boris Diaw   2    0    2
# Channing Frye      1   Channing  17   6    4      Channing Frye   0    1    1
# Danny Green        2      Danny  25   6    7        Danny Green   2    2    0
# David West         2      David  17   3    0         David West   1    0    0
# Dewayne Dedmon     0    Dewayne   3   0    0     Dewayne Dedmon   0    0    0
# Elfrid Payton      1     Elfrid  32   5    1      Elfrid Payton   8    0    3
# Evan Fournier      3       Evan  18   1    2      Evan Fournier   0    1    1
# Jason Smith        0      Jason  11   3    0        Jason Smith   0    0    2
# Jonathon Simmons   1   Jonathon  16   1    0   Jonathon Simmons   1    0    0
# Kawhi Leonard      2      Kawhi  26   5    7      Kawhi Leonard   2    2    0
# Keith Appling      0      Keith   3   0    0      Keith Appling   0    0    0
# Kyle Anderson      1       Kyle  22   4    1      Kyle Anderson   5    1    0
# LaMarcus Aldridge  1   LaMarcus  32   4    0  LaMarcus Aldridge   0    0    1
# Manu Ginobili      0       Manu  17   2    4      Manu Ginobili   2    1    1
# Mario Hezonja      2      Mario  29   2    2      Mario Hezonja   1    0    0
# Nikola Vucevic     0     Nikola  31  10    0     Nikola Vucevic   3    0    5
# Patty Mills        1      Patty  21   4    4        Patty Mills   5    3    0
# Rasual Butler      0     Rasual   8   4    0      Rasual Butler   0    0    0
# Ray McCallum       0        Ray  11   0    1       Ray McCallum   1    0    0
# Shabazz Napier     0    Shabazz   3   1    1     Shabazz Napier   0    1    0
# Tobias Harris      3     Tobias  25   4    3      Tobias Harris   0    1    1
# Tony Parker        3       Tony  25   3    0        Tony Parker   6    0    1
# Victor Oladipo     4     Victor  35   3    4     Victor Oladipo   7    1    0
#
#                   FGM START_POSITION PF PTS FGA STL FTA BLK DREB FTM FT_PCT  \
# Aaron Gordon        6              F  1  12  12   0   0   1   10   0      0
# Andrew Nicholson    0            N/A  0   0   0   0   0   0    0   0      0
# Boban Marjanovic    0            N/A  0   2   0   0   2   1    0   2    100
# Boris Diaw          1              C  0   2   1   1   0   0    4   0      0
# Channing Frye       3            N/A  3   7   7   0   0   0    5   0      0
# Danny Green         3              G  5   8   9   1   0   0    6   0      0
# David West          3            N/A  4   6   5   0   0   0    3   0      0
# Dewayne Dedmon      1            N/A  1   2   2   0   0   0    0   0      0
# Elfrid Payton       3              G  2   6  12   1   1   1    2   0      0
# Evan Fournier       2            N/A  1   5   5   0   0   0    0   0      0
# Jason Smith         1            N/A  0   3   4   0   2   2    1   1     50
# Jonathon Simmons    2            N/A  1   4   5   0   0   0    1   0      0
# Kawhi Leonard       4              F  1  10  11   1   0   2    5   0      0
# Keith Appling       0            N/A  0   0   0   0   0   0    0   0      0
# Kyle Anderson       4            N/A  0   9   7   0   0   0    4   0      0
# LaMarcus Aldridge   9              F  1  28  13   0  12   5    3  10     83
# Manu Ginobili       4            N/A  0  13   8   2   4   0    1   4    100
# Mario Hezonja       2            N/A  2   4   8   2   0   1    2   0      0
# Nikola Vucevic      9              C  4  20  20   1   2   1    5   2    100
# Patty Mills         9            N/A  1  22  13   1   1   0    4   1    100
# Rasual Butler       0            N/A  0   0   1   0   0   1    4   0      0
# Ray McCallum        0            N/A  0   0   1   0   0   1    0   0      0
# Shabazz Napier      1            N/A  0   3   1   0   0   0    1   0      0
# Tobias Harris       5              F  2  11   9   0   0   0    3   0      0
# Tony Parker         1              G  1   3   4   0   2   0    2   1     50
# Victor Oladipo      6              G  3  19  16   5   6   0    3   6    100
#
#                   FG_PCT FG3_PCT SECOND_NAME    TEAM_CITY
# Aaron Gordon          50       0      Gordon      Orlando
# Andrew Nicholson       0       0   Nicholson      Orlando
# Boban Marjanovic       0       0  Marjanovic  San Antonio
# Boris Diaw           100       0        Diaw  San Antonio
# Channing Frye         43      25        Frye      Orlando
# Danny Green           33      29       Green  San Antonio
# David West            60       0        West  San Antonio
# Dewayne Dedmon        50       0      Dedmon      Orlando
# Elfrid Payton         25       0      Payton      Orlando
# Evan Fournier         40      50    Fournier      Orlando
# Jason Smith           25       0       Smith      Orlando
# Jonathon Simmons      40       0     Simmons  San Antonio
# Kawhi Leonard         36      29     Leonard  San Antonio
# Keith Appling          0       0     Appling      Orlando
# Kyle Anderson         57     100    Anderson  San Antonio
# LaMarcus Aldridge     69       0    Aldridge  San Antonio
# Manu Ginobili         50      25    Ginobili  San Antonio
# Mario Hezonja         25       0     Hezonja      Orlando
# Nikola Vucevic        45       0     Vucevic      Orlando
# Patty Mills           69      75       Mills  San Antonio
# Rasual Butler          0       0      Butler  San Antonio
# Ray McCallum           0       0    McCallum  San Antonio
# Shabazz Napier       100     100      Napier      Orlando
# Tobias Harris         56      33      Harris      Orlando
# Tony Parker           25       0      Parker  San Antonio
# Victor Oladipo        38      25     Oladipo      Orlando

# %% [markdown]
# #### 2.2.2 team stat 보기

# %%
def view_team_stat(data, i, team):
    """i번째 기록에서 home 혹은 away 팀에 대한 기록 보기"""
    assert team in {'home', 'away'}
    def rename(team):
        rename_dict = {'home': 'home_line', 'away': 'vis_line'}
        return rename_dict[team]
    record = get_ith_record(data, i)
    team_stat = record[rename(team)]
    return pd.DataFrame(team_stat, index=[0])

# %%
view_team_stat(train, i, 'home')
# Out:
#   TEAM-PTS_QTR2 TEAM-FT_PCT TEAM-PTS_QTR1 TEAM-PTS_QTR4 TEAM-PTS_QTR3  \
# 0            30          88            26            34            17
#
#      TEAM-CITY TEAM-PTS TEAM-AST TEAM-LOSSES TEAM-NAME TEAM-WINS TEAM-REB  \
# 0  Los Angeles      107       28           1  Clippers         3       35
#
#   TEAM-TOV TEAM-FG3_PCT TEAM-FG_PCT
# 0       10           44          51

# %%
view_team_stat(train, i, 'away')
# Out:
#   TEAM-PTS_QTR2 TEAM-FT_PCT TEAM-PTS_QTR1 TEAM-PTS_QTR4 TEAM-PTS_QTR3  \
# 0            23          79            20            31            27
#
#   TEAM-CITY TEAM-PTS TEAM-AST TEAM-LOSSES TEAM-NAME TEAM-WINS TEAM-REB  \
# 0      Utah      101       24           3      Jazz         1       43
#
#   TEAM-TOV TEAM-FG3_PCT TEAM-FG_PCT
# 0       17           37          47

# %%
df = view_player_stat(train, 3)
df2 = view_team_stat(train, 3, 'away')
df3 = view_team_stat(train, 3, 'home')
types = set(list(df.columns) + list(df2.columns) + list(df3.columns))
print(sorted(types), len(types))
# Out:
# ['AST', 'BLK', 'DREB', 'FG3A', 'FG3M', 'FG3_PCT', 'FGA', 'FGM', 'FG_PCT', 'FIRST_NAME', 'FTA', 'FTM', 'FT_PCT', 'MIN', 'OREB', 'PF', 'PLAYER_NAME', 'PTS', 'REB', 'SECOND_NAME', 'START_POSITION', 'STL', 'TEAM-AST', 'TEAM-CITY', 'TEAM-FG3_PCT', 'TEAM-FG_PCT', 'TEAM-FT_PCT', 'TEAM-LOSSES', 'TEAM-NAME', 'TEAM-PTS', 'TEAM-PTS_QTR1', 'TEAM-PTS_QTR2', 'TEAM-PTS_QTR3', 'TEAM-PTS_QTR4', 'TEAM-REB', 'TEAM-TOV', 'TEAM-WINS', 'TEAM_CITY', 'TO'] 39

# %% [markdown]
# #### 2.2.3 summary 보기

# %%
def view_summary(data, i=None):
    """i번째 기록에 대한 summary text보기"""
    record = get_ith_record(data, i)
    return ' '.join(record['summary'])

# %%
view_summary(train, i)
# Out:
# "The Los Angeles Clippers ( 3 - 1 ) defeated the Utah Jazz ( 1 - 3 ) 107 - 101 on Monday . Chris Paul recorded the NBA 's first triple - double of the 2014 - 15 season , putting up 13 points , 10 rebounds , and 12 assists in 36 minutes . He also threw in two steals and a blocked shot for good measure . Teammate Blake Griffin helped Paul convert some of those assists , shooting 14 - of - 21 from the field and finishing with 31 points in 38 minutes . J.J. Redick started at shooting guard but played a season - low 16 minutes as coach Doc Rivers opted to go with Jamal Crawford most of the night . Crawford missed the Clippers ' last game with a rib injury but returned to put up 19 points off the bench in 34 minutes . Gordon Hayward put up a LeBron James-esque line of 27 points , seven rebounds , and five assists in 36 minutes . He was aided in keeping the game close by starting power forward Enes Kanter who put up 17 points and nine rebounds in 27 minutes . The Jazz were relatively efficient with their shooting , but they committed 17 turnovers in contrast to the Clippers ' 10 , giving away the game in some respects . The Clippers ' next game is against the Golden State Warriors on Wednesday , while the Jazz will return home to face the Cleveland Cavaliers on Wednesday ."

# %% [markdown]
# ### 2.3 한 번에 보기

# %%
data = train
i = 189

# %%
display(view_team_stat(train, i, 'home'))
display(view_team_stat(train, i, 'away'))
display(view_summary(train, i))
display(view_player_stat(train, i))
# Out:
#   TEAM-PTS_QTR2 TEAM-FT_PCT TEAM-PTS_QTR1 TEAM-PTS_QTR4 TEAM-PTS_QTR3  \
# 0            28          78            34            15            26
#
#    TEAM-CITY TEAM-PTS TEAM-AST TEAM-LOSSES     TEAM-NAME TEAM-WINS TEAM-REB  \
# 0  Minnesota      103       21          37  Timberwolves        27       46
#
#   TEAM-TOV TEAM-FG3_PCT TEAM-FG_PCT
# 0       11           29          44
#   TEAM-PTS_QTR2 TEAM-FT_PCT TEAM-PTS_QTR1 TEAM-PTS_QTR4 TEAM-PTS_QTR3  \
# 0            29          77            24            26            23
#
#       TEAM-CITY TEAM-PTS TEAM-AST TEAM-LOSSES TEAM-NAME TEAM-WINS TEAM-REB  \
# 0  Golden State      102       25          13  Warriors        52       43
#
#   TEAM-TOV TEAM-FG3_PCT TEAM-FG_PCT
# 0       12           29          47
# "The Minnesota Timberwolves defeated the visiting Golden State Warriors 103 - 102 , at Target Center , on Friday evening . It was a dramatic contest , as the Timberwolves jumped out to a 10 - point lead , with a 34 - 24 first quarter . The Warriors responded in the second , where they out - scored the T-Wolves by one . The Timberwolves came back strong in the third , ensuring themselves a 12 - point lead heading into the final quarter . Minnesota then extended their lead to 14 , however the Warriors went on a 130 run to bring the game within one point with 7:28 to go . It was then back and forth , with the T-Wolves staying on top , until the Warriors tied it up with 2:37 left . Minnesota battled ahead once again but almost let it slip away as they were up by one , when Andrew Wiggins missed two free throws , allowing the Warriors the opportunity to go up by one on the next possession . Wiggins made up for his error though , as he sank two free throws with 12 seconds left to seal the one - point win . Andrew Wiggins was the high - point man for the Timberwolves ( 27 - 37 ) , as he finished with 24 points on 9 - of - 21 shooting , in 37 minutes . Karl-Anthony Towns followed up with 23 points on more efficient 10 - of - 18 shooting , in 38 minutes . This marked Towns ' 19th straight game with 20 or more points . Four other players scored in double digits for Minnesota , including Ricky Rubio , who chipped in 17 points and dished 13 assists , in 36 minutes . The T-Wolves go on to face the second night of a back - to - back as they visit Milwaukee on Saturday . Klay Thompson led the way for the Warriors ( 52 - 13 ) with a game - high 30 points on 12 - of - 22 shooting , while Stephen Curry followed up with 26 points , but struggled from deep , where he went 1 - of - 8 , in 35 minutes . The only other player to score in double digits for Golden State was Ian Clark , who added 10 points off the bench . The Warriors have now lost two straight , and face a tough match up in their next contest , when they visit San Antonio on Saturday ."
#                         FIRST_NAME  MIN  FGM  REB FG3A           PLAYER_NAME  \
# Adreian Payne              Adreian  N/A  N/A  N/A  N/A         Adreian Payne
# Andre Iguodala               Andre   32    4    2    1        Andre Iguodala
# Andrew Wiggins              Andrew   37    9    4    1        Andrew Wiggins
# Brandon Rush               Brandon   20    1    3    1          Brandon Rush
# Cole Aldrich                  Cole  N/A  N/A  N/A  N/A          Cole Aldrich
# David West                   David   13    0    4    1            David West
# Draymond Green            Draymond   38    1    7    3        Draymond Green
# Gorgui Dieng                Gorgui   24    5    4    0          Gorgui Dieng
# Ian Clark                      Ian   13    4    4    3             Ian Clark
# JaVale McGee                JaVale    9    1    3    0          JaVale McGee
# James Michael McAdoo         James  N/A  N/A  N/A  N/A  James Michael McAdoo
# Jordan Hill                 Jordan  N/A  N/A  N/A  N/A           Jordan Hill
# Karl-Anthony Towns    Karl-Anthony   38   10    9    4    Karl-Anthony Towns
# Kevon Looney                 Kevon    2    0    1    0          Kevon Looney
# Klay Thompson                 Klay   36   12    5    6         Klay Thompson
# Kris Dunn                     Kris   12    1    2    0             Kris Dunn
# Lance Stephenson             Lance  N/A  N/A  N/A  N/A      Lance Stephenson
# Matt Barnes                   Matt   10    2    2    1           Matt Barnes
# Nemanja Bjelica            Nemanja   34    4   12    4       Nemanja Bjelica
# Patrick McCaw              Patrick   25    3    4    1         Patrick McCaw
# Ricky Rubio                  Ricky   36    3    4    1           Ricky Rubio
# Shabazz Muhammad           Shabazz   28    5    7    2      Shabazz Muhammad
# Shaun Livingston             Shaun  N/A  N/A  N/A  N/A      Shaun Livingston
# Stephen Curry              Stephen   35   10    6    8         Stephen Curry
# Tyus Jones                    Tyus   11    1    1    1            Tyus Jones
# Zaza Pachulia                 Zaza   26    4    5    0         Zaza Pachulia
#
#                       AST FG3M OREB   TO START_POSITION   PF  PTS  FGA  STL  \
# Adreian Payne         N/A  N/A  N/A  N/A            N/A  N/A  N/A  N/A  N/A
# Andre Iguodala          1    0    2    0            N/A    0    8    6    1
# Andrew Wiggins          0    1    2    4              F    3   24   21    2
# Brandon Rush            3    0    2    0              G    1    2    3    1
# Cole Aldrich          N/A  N/A  N/A  N/A            N/A  N/A  N/A  N/A  N/A
# David West              1    0    0    0            N/A    1    0    3    0
# Draymond Green          7    0    3    0              F    4    5    8    2
# Gorgui Dieng            0    0    0    0              F    2   12   10    1
# Ian Clark               2    2    1    0            N/A    0   10    7    1
# JaVale McGee            0    0    1    1            N/A    2    3    2    0
# James Michael McAdoo  N/A  N/A  N/A  N/A            N/A  N/A  N/A  N/A  N/A
# Jordan Hill           N/A  N/A  N/A  N/A            N/A  N/A  N/A  N/A  N/A
# Karl-Anthony Towns      2    2    2    3              C    4   23   18    0
# Kevon Looney            0    0    0    1            N/A    0    0    0    0
# Klay Thompson           2    3    0    2              G    1   30   22    1
# Kris Dunn               0    0    0    1            N/A    1    2    4    1
# Lance Stephenson      N/A  N/A  N/A  N/A            N/A  N/A  N/A  N/A  N/A
# Matt Barnes             1    1    0    0            N/A    3    5    2    0
# Nemanja Bjelica         2    1    5    0            N/A    3   10   10    0
# Patrick McCaw           1    0    1    1              F    0    6    7    0
# Ricky Rubio            13    0    1    2              G    3   17   10    1
# Shabazz Muhammad        0    0    2    1            N/A    1   11    9    0
# Shaun Livingston      N/A  N/A  N/A  N/A            N/A  N/A  N/A  N/A  N/A
# Stephen Curry           7    1    3    6              G    4   26   27    1
# Tyus Jones              1    0    0    0            N/A    0    2    3    0
# Zaza Pachulia           3    0    1    1              C    6    9    4    3
#
#                       FTA  BLK DREB  FTM FT_PCT FG_PCT FG3_PCT SECOND_NAME  \
# Adreian Payne         N/A  N/A  N/A  N/A    N/A    N/A     N/A       Payne
# Andre Iguodala          0    0    0    0      0     67       0    Iguodala
# Andrew Wiggins          7    0    2    5     71     43     100     Wiggins
# Brandon Rush            0    0    1    0      0     33       0        Rush
# Cole Aldrich          N/A  N/A  N/A  N/A    N/A    N/A     N/A     Aldrich
# David West              0    0    4    0      0      0       0        West
# Draymond Green          4    1    4    3     75     13       0       Green
# Gorgui Dieng            2    1    4    2    100     50       0       Dieng
# Ian Clark               0    0    3    0      0     57      67       Clark
# JaVale McGee            2    3    2    1     50     50       0       McGee
# James Michael McAdoo  N/A  N/A  N/A  N/A    N/A    N/A     N/A     Michael
# Jordan Hill           N/A  N/A  N/A  N/A    N/A    N/A     N/A        Hill
# Karl-Anthony Towns      3    2    7    1     33     56      50       Towns
# Kevon Looney            0    0    1    0      0      0       0      Looney
# Klay Thompson           4    0    5    3     75     55      50    Thompson
# Kris Dunn               0    0    2    0      0     25       0        Dunn
# Lance Stephenson      N/A  N/A  N/A  N/A    N/A    N/A     N/A  Stephenson
# Matt Barnes             0    0    2    0      0    100     100      Barnes
# Nemanja Bjelica         2    0    7    1     50     40      25     Bjelica
# Patrick McCaw           0    0    3    0      0     43       0       McCaw
# Ricky Rubio            11    0    3   11    100     30       0       Rubio
# Shabazz Muhammad        2    0    5    1     50     56       0    Muhammad
# Shaun Livingston      N/A  N/A  N/A  N/A    N/A    N/A     N/A  Livingston
# Stephen Curry           5    0    3    5    100     37      13       Curry
# Tyus Jones              0    0    1    0      0     33       0       Jones
# Zaza Pachulia           2    1    4    1     50    100       0    Pachulia
#
#                          TEAM_CITY
# Adreian Payne            Minnesota
# Andre Iguodala        Golden State
# Andrew Wiggins           Minnesota
# Brandon Rush             Minnesota
# Cole Aldrich             Minnesota
# David West            Golden State
# Draymond Green        Golden State
# Gorgui Dieng             Minnesota
# Ian Clark             Golden State
# JaVale McGee          Golden State
# James Michael McAdoo  Golden State
# Jordan Hill              Minnesota
# Karl-Anthony Towns       Minnesota
# Kevon Looney          Golden State
# Klay Thompson         Golden State
# Kris Dunn                Minnesota
# Lance Stephenson         Minnesota
# Matt Barnes           Golden State
# Nemanja Bjelica          Minnesota
# Patrick McCaw         Golden State
# Ricky Rubio              Minnesota
# Shabazz Muhammad         Minnesota
# Shaun Livingston      Golden State
# Stephen Curry         Golden State
# Tyus Jones               Minnesota
# Zaza Pachulia         Golden State

# %%
df1 = view_player_stat(train, 3)
df2 = view_team_stat(train, 3, 'home')

# %%
len(df2.columns)
# Out:
# 15
